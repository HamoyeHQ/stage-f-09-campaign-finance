# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats

# %%
pd.options.display.max_columns = 50

# %%
data_df = pd.read_csv('CandidateSummaryAction0.csv')

# %%
summary = pd.DataFrame({'null_values': data_df.isnull().sum(), 'datatypes' :data_df.dtypes})
summary = summary.reset_index()

# %%
second_data = pd.read_html('https://web.archive.org/web/20170118212350/http://www.fec.gov/finance/disclosure/metadata/metadataforcandidatesummary.shtml')

# %%
data_dictionary = second_data[2]
data_dictionary.columns = data_dictionary.iloc[0, :]

# %%
data_dic = data_dictionary.drop([0, 1], axis = 0)
data_dic = data_dic.reset_index(drop = True)
data_dic.head()
# Out:
# 0          Tag                 Field Name  Data Type  \
# 0       can_id               Candidate Id  Character
# 1      can_nam             Candidate Name  Character
# 2      can_off           Candidate Office       Text
# 3  can_off_sta     Candidate Office State  Character
# 4  can_off_dis  Candidate Office District     Number
#
# 0                           Description              Range  \
# 0                                   NaN       9 characters
# 1                     Name of candidate  Max 90 characters
# 2                   office abbreviation        1 character
# 3         Postal abbreviation for state       2 characters
# 4  District number for House candidates           2 digits
#
# 0                                        Explanation
# 0  First character indicates office sought - H=Ho...
# 1                                                NaN
# 2                     P=President; S=Senate; H=House
# 3                                                NaN
# 4                                                NaN

# %%
data_dic.to_csv('data_dic.csv')

# %%
frame = [['winner', 0,'object',0,0,0], ['votes', 0,'float',0,0,0]]

winners_votes = pd.DataFrame(frame, columns = data_dic.columns, index = [49, 50])
data_dic = pd.concat([data_dic, winners_votes], axis = 0)
data_dic.head()
# Out:
# 0          Tag                 Field Name  Data Type  \
# 0       can_id               Candidate Id  Character
# 1      can_nam             Candidate Name  Character
# 2      can_off           Candidate Office       Text
# 3  can_off_sta     Candidate Office State  Character
# 4  can_off_dis  Candidate Office District     Number
#
# 0                           Description              Range  \
# 0                                   NaN       9 characters
# 1                     Name of candidate  Max 90 characters
# 2                   office abbreviation        1 character
# 3         Postal abbreviation for state       2 characters
# 4  District number for House candidates           2 digits
#
# 0                                        Explanation
# 0  First character indicates office sought - H=Ho...
# 1                                                NaN
# 2                     P=President; S=Senate; H=House
# 3                                                NaN
# 4                                                NaN

# %%
summary['correct_dtypes'] = data_dic['Data Type']
summary
# Out:
#                     index  null_values datatypes correct_dtypes
# 0                  can_id            0    object      Character
# 1                 can_nam            0    object      Character
# 2                 can_off            0    object           Text
# 3             can_off_sta            0    object      Character
# 4             can_off_dis            2   float64         Number
# 5             can_par_aff            1    object      Character
# 6     can_inc_cha_ope_sea            2    object      Character
# 7                can_str1           25    object           Text
# 8                can_str2         1692    object           Text
# 9                 can_cit            1    object           Text
# 10                can_sta            8    object           Text
# 11                can_zip           25   float64         Number
# 12            ind_ite_con          244   float64       Currency
# 13            ind_uni_con          276   float64       Currency
# 14                ind_con          198   float64       Currency
# 15            par_com_con         1432   float64       Currency
# 16            oth_com_con          803   float64       Currency
# 17                can_con         1139   float64       Currency
# 18                tot_con          119   float64       Currency
# 19    tra_fro_oth_aut_com         1553   float64       Currency
# 20                can_loa         1174   float64       Currency
# 21                oth_loa         1747   float64       Currency
# 22                tot_loa         1161   float64       Currency
# 23         off_to_ope_exp         1051   float64       Currency
# 24             off_to_fun         1810   float64       Currency
# 25         off_to_leg_acc         1813   float64       Currency
# 26                oth_rec         1280   float64       Currency
# 27                tot_rec           93   float64       Currency
# 28                ope_exp           97   float64       Currency
# 29        exe_leg_acc_dis         1808   float64       Currency
# 30                fun_dis         1799   float64       Currency
# 31     tra_to_oth_aut_com         1661   float64       Currency
# 32            can_loa_rep         1520   float64       Currency
# 33            oth_loa_rep         1781   float64       Currency
# 34            tot_loa_rep         1508   float64       Currency
# 35                ind_ref          983   float64       Currency
# 36            par_com_ref         1790   float64       Currency
# 37            oth_com_ref         1452   float64       Currency
# 38            tot_con_ref          942   float64       Currency
# 39                oth_dis         1019   float64       Currency
# 40                tot_dis           84   float64       Currency
# 41  cas_on_han_beg_of_per         1114   float64       Currency
# 42  cas_on_han_clo_of_per          380   float64       Currency
# 43                net_con          171   float64       Currency
# 44            net_ope_exp          149   float64       Currency
# 45         deb_owe_by_com         1082   float64       Currency
# 46         deb_owe_to_com         1791   float64       Currency
# 47            cov_sta_dat            0    object           Date
# 48            cov_end_dat            0    object           Date
# 49                 winner         1343    object         object
# 50                  votes         1435   float64          float

# %%
curr_col = summary[summary['correct_dtypes'] == 'Currency']['index'].to_list()

# %%
# conerting currency columns to floats

def split_join(col):
    if type(col) == str:
        l = []
        for string in re.split('', col):
            if string.isdigit():
                pass
            else:
                l.append(string)
        l.remove('.')
        split_criterion = '[' + ''.join(list(set(l))) + ']'
        output = ''.join(re.split(split_criterion, col))
        return float(output)
    else:
        return col
for col in curr_col:
    data_df[col] = data_df[col].apply(split_join)
data_df
# Out:
#          can_id                       can_nam can_off can_off_sta  \
# 0     H2GA12121              ALLEN, RICHARD W       H          GA
# 1     H6PA02171                 EVANS, DWIGHT       H          PA
# 2     H6FL04105              RUTHERFORD, JOHN       H          FL
# 3     H4MT01041                 ZINKE, RYAN K       H          MT
# 4     H8CA09060                  LEE, BARBARA       H          CA
# ...         ...                           ...     ...         ...
# 1809  P60005931   BUTTOCKS, SYDNEYS VOLUPTOUS       P          US
# 1810  S6CA00568                MOLNAR, ROBERT       S          CA
# 1811  S6MD03524               HOLMES, GREGORY       S          MD
# 1812  H6AS00031  HUNKIN-FINAU, VAITINASA SALU       H          AS
# 1813  H6AK00235               LINDBECK, STEVE       H          AK
#
#       can_off_dis can_par_aff can_inc_cha_ope_sea                 can_str1  \
# 0            12.0         REP           INCUMBENT          2237 PICKENS RD
# 1             2.0         DEM          CHALLENGER              PO BOX 6578
# 2             4.0         REP                OPEN  3817 VICKERS LAKE DRIVE
# 3             0.0         REP           INCUMBENT             409 2ND ST W
# 4            13.0         DEM           INCUMBENT     409 13TH ST, 17TH FL
# ...           ...         ...                 ...                      ...
# 1809          0.0         IND                OPEN      143 HIGHLAND AVENUE
# 1810          0.0         REP                OPEN            PO BOX 321231
# 1811          0.0         REP                OPEN       13601 MACDERNUT CT
# 1812          NaN         DEM                 NaN     PO BOX 252 VAILOAUTA
# 1813          NaN         DEM                 NaN             PO BOX 90025
#
#      can_str2         can_cit  ... cas_on_han_beg_of_per  \
# 0         NaN         AUGUSTA  ...              60109.57
# 1         NaN    PHILADELPHIA  ...                   NaN
# 2         NaN    JACKSONVILLE  ...                   NaN
# 3         NaN       WHITEFISH  ...              83815.78
# 4         NaN         OAKLAND  ...              83690.60
# ...       ...             ...  ...                   ...
# 1809      NaN         BUFFALO  ...               5000.00
# 1810      NaN       LOS GATOS  ...               1000.00
# 1811      NaN  UPPER MARLBORO  ...                   NaN
# 1812      NaN       PAGO PAGO  ...               1058.44
# 1813      NaN       ANCHORAGE  ...                   NaN
#
#       cas_on_han_clo_of_per     net_con  net_ope_exp  deb_owe_by_com  \
# 0                 175613.35  1074949.50    907156.21      1125000.00
# 1                 105687.23  1406719.06   1298831.83             NaN
# 2                  35645.09   650855.38    656210.29        60000.00
# 3                 399122.61  4938943.74   5055942.15             NaN
# 4                 181338.23  1197676.61    949488.98         4401.75
# ...                     ...         ...          ...             ...
# 1809                5000.00         NaN          NaN             NaN
# 1810                    NaN     1000.00      1000.00             NaN
# 1811                    NaN         NaN          NaN             NaN
# 1812                4561.00    41670.00     38167.44             NaN
# 1813               64115.92   876316.81    792150.89        13979.83
#
#       deb_owe_to_com  cov_sta_dat  cov_end_dat  winner     votes
# 0                NaN     1/1/2015   10/19/2016       Y  158708.0
# 1                NaN    11/2/2015   10/19/2016       Y  310770.0
# 2                NaN     4/1/2016   10/19/2016       Y  286018.0
# 3                NaN     1/1/2015   10/19/2016       Y  280476.0
# 4                NaN     1/1/2015   10/19/2016       Y  277390.0
# ...              ...          ...          ...     ...       ...
# 1809             NaN     3/3/2015    3/31/2015     NaN       NaN
# 1810             NaN     1/1/2015    3/31/2015     NaN       NaN
# 1811             NaN    8/29/2017     2/1/2015     NaN       NaN
# 1812             NaN     7/1/2016   10/19/2016     NaN       NaN
# 1813             NaN     4/1/2016   10/19/2016     NaN       NaN
#
# [1814 rows x 51 columns]

# %%
def get_high_correlations(df, correlation = 0.5):
    # it gets the number (n) pairs with the highest correlation
    # ##########
    matrix = df.corr()
    matrix = matrix * np.tri(*matrix.values.shape, k=-1).T
    # stack the matrix
    matrix = matrix.stack()
    matrix = matrix.reindex(matrix.abs().sort_values(ascending = False).index).reset_index()
    
    # assign names to columns
    matrix.columns = ['var1', 'var2', 'correlation']
    matrix= matrix[matrix['correlation'] != 0]
    matrix = matrix[matrix['correlation'] >= correlation]
    return matrix

# %%
# check if columns that have high correlations, have low number of missing values
# check for the columns that appear most having high correlations
from collections import Counter

def check_highest_corr(df, num_null = 200):
    
    high_correlations = get_high_correlations(df)
    high_corr_list1 = high_correlations['var1'].to_list()
    high_corr_list2 = high_correlations['var2'].to_list()

    high_corr_list = high_corr_list1  + high_corr_list2
    
    # count the columns to get the number of times they appear as high correlations
    dic1 = Counter(high_corr_list)
    
    high_dic_keys = [key for key, value in dic1.items() if value >= 1]

    # get columns with not more than 200 missing values
    summary_currency = summary[summary['correct_dtypes'] == 'Currency']
    summary_currency = summary_currency.sort_values('null_values')
    summary_currency = summary_currency[summary_currency['null_values'] <= num_null]
    low_null_values = summary_currency['index'].to_list()

    
    return list(set(high_dic_keys).intersection(set(low_null_values)))

# %%
retained_list = check_highest_corr(df_currency, 200)

# %%
# get data with the retained lists of columns and join to other non currency columns

df1 = data_df.drop(columns = curr_col)
df2 = data_df[retained_list]

data_df_new = pd.concat([df1, df2], axis = 1)
columns = list(data_df_new.columns)
columns.remove('winner')
columns.remove('votes')

columns.extend(['votes', 'winner'])

data_df_new = data_df_new.loc[:, columns]

data_df_new.head()
# Out:
#       can_id           can_nam can_off can_off_sta  can_off_dis can_par_aff  \
# 0  H2GA12121  ALLEN, RICHARD W       H          GA         12.0         REP
# 1  H6PA02171     EVANS, DWIGHT       H          PA          2.0         DEM
# 2  H6FL04105  RUTHERFORD, JOHN       H          FL          4.0         REP
# 3  H4MT01041     ZINKE, RYAN K       H          MT          0.0         REP
# 4  H8CA09060      LEE, BARBARA       H          CA         13.0         DEM
#
#   can_inc_cha_ope_sea                 can_str1 can_str2       can_cit can_sta  \
# 0           INCUMBENT          2237 PICKENS RD      NaN       AUGUSTA      GA
# 1          CHALLENGER              PO BOX 6578      NaN  PHILADELPHIA      PA
# 2                OPEN  3817 VICKERS LAKE DRIVE      NaN  JACKSONVILLE      FL
# 3           INCUMBENT             409 2ND ST W      NaN     WHITEFISH      MT
# 4           INCUMBENT     409 13TH ST, 17TH FL      NaN       OAKLAND      CA
#
#        can_zip cov_sta_dat cov_end_dat     ind_con  net_ope_exp     tot_con  \
# 0      30904.0    1/1/2015  10/19/2016   601274.50    907156.21  1074949.50
# 1      19138.0   11/2/2015  10/19/2016  1114711.02   1298831.83  1417545.22
# 2      32224.0    4/1/2016  10/19/2016   542105.38    656210.29   650855.38
# 3  599373010.0    1/1/2015  10/19/2016  4317331.58   5055942.15  4980915.41
# 4      94612.0    1/1/2015  10/19/2016   897123.61    949488.98  1205863.61
#
#       tot_dis     net_con     ope_exp     tot_rec     votes winner
# 0   978518.98  1074949.50   908518.98  1094022.76  158708.0      Y
# 1  1313583.69  1406719.06  1300557.53  1419270.92  310770.0      Y
# 2   675642.76   650855.38   656642.76   711287.85  286018.0      Y
# 3  5200630.00  4938943.74  5073110.33  5190887.78  280476.0      Y
# 4  1112163.94  1197676.61   953436.94  1209811.57  277390.0      Y

# %%
df_dem = data_df_new[data_df_new['can_off_dis'] == 12.0]

df_dem[retained_list].hist(figsize = (16, 10), bins = 12);

# %%
data_df_new['winner'] = data_df_new['winner'].fillna('N')

# %%
# dropping irrelevant columns

data_df_new = data_df_new.drop(columns = ['can_str1', 'can_str2', 'votes'])

# %%
data_df_new.isnull().sum()
# Out:
# can_id                   0
# can_nam                  0
# can_off                  0
# can_off_sta              0
# can_off_dis              2
# can_par_aff              1
# can_inc_cha_ope_sea      2
# can_cit                  1
# can_sta                  8
# can_zip                 25
# cov_sta_dat              0
# cov_end_dat              0
# ind_con                198
# net_ope_exp            149
# tot_con                119
# tot_dis                 84
# net_con                171
# ope_exp                 97
# tot_rec                 93
# winner                   0
# dtype: int64

# %%
final_data
# Out:
#          can_id                   can_nam can_off can_off_sta  can_off_dis  \
# 0     H2GA12121          ALLEN, RICHARD W       H          GA         12.0
# 1     H6PA02171             EVANS, DWIGHT       H          PA          2.0
# 2     H6FL04105          RUTHERFORD, JOHN       H          FL          4.0
# 3     H4MT01041             ZINKE, RYAN K       H          MT          0.0
# 4     H8CA09060              LEE, BARBARA       H          CA         13.0
# ...         ...                       ...     ...         ...          ...
# 1792  P00004275           BROWN, HARLEY D       P          US          0.0
# 1793  H6NY11182               LANE, JAMES       H          NY         11.0
# 1794  H6MS01164            COLLINS, NANCY       H          MS          1.0
# 1795  S6CA00618        ALBERTSON, STEWART       S          CA          0.0
# 1800  H6MS01198  JONES, ROGER STARNER DR.       H          MS          1.0
#
#      can_par_aff can_inc_cha_ope_sea       can_cit can_sta      can_zip  \
# 0            REP           INCUMBENT       AUGUSTA      GA      30904.0
# 1            DEM          CHALLENGER  PHILADELPHIA      PA      19138.0
# 2            REP                OPEN  JACKSONVILLE      FL      32224.0
# 3            REP           INCUMBENT     WHITEFISH      MT  599373010.0
# 4            DEM           INCUMBENT       OAKLAND      CA      94612.0
# ...          ...                 ...           ...     ...          ...
# 1792         NNE                OPEN         NAMPA      ID      83686.0
# 1793         GRE                OPEN      BROOKLYN      NY      11215.0
# 1794         REP                OPEN        TUPELO      MS      38804.0
# 1795         DEM                OPEN  REDWOOD CITY      CA      94065.0
# 1800         REP                OPEN      PONTOTOC      MS      38863.0
#
#      cov_sta_dat cov_end_dat     ind_con  net_ope_exp     tot_con     tot_dis  \
# 0       1/1/2015  10/19/2016   601274.50    907156.21  1074949.50   978518.98
# 1      11/2/2015  10/19/2016  1114711.02   1298831.83  1417545.22  1313583.69
# 2       4/1/2016  10/19/2016   542105.38    656210.29   650855.38   675642.76
# 3       1/1/2015  10/19/2016  4317331.58   5055942.15  4980915.41  5200630.00
# 4       1/1/2015  10/19/2016   897123.61    949488.98  1205863.61  1112163.94
# ...          ...         ...         ...          ...         ...         ...
# 1792    1/1/2015    7/8/2015      215.00      9655.02    12847.39    11683.89
# 1793    1/1/2015    7/7/2015    12889.00     13356.89    14241.00    13983.11
# 1794    1/1/2015    7/1/2015    95538.35    247121.35   102538.35   247121.35
# 1795    1/1/2015   6/30/2015    18949.00     15221.00    20949.00    30949.00
# 1800    1/1/2015   6/30/2015    25808.00    528638.39   140858.00   538358.00
#
#          net_con     ope_exp     tot_rec winner
# 0     1074949.50   908518.98  1094022.76      Y
# 1     1406719.06  1300557.53  1419270.92      Y
# 2      650855.38   656642.76   711287.85      Y
# 3     4938943.74  5073110.33  5190887.78      Y
# 4     1197676.61   953436.94  1209811.57      Y
# ...          ...         ...         ...    ...
# 1792    10487.10    11683.89    12847.39      N
# 1793    14241.00    13356.89    14241.00      N
# 1794   102538.35   247121.35   247121.35      N
# 1795    15250.00    15221.00    30949.00      N
# 1800   140858.00   528638.39   538358.00      N
#
# [1551 rows x 20 columns]

# %%
final_data.to_csv('new_project_data.csv', index=False)
